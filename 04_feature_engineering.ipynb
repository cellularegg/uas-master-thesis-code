# %% [markdown]
# # 04 — Feature engineering
#
# Builds the feature matrix used by the training notebooks.
#
# **Inputs:** `data/processed/{station_id}_train_splits.parquet`, `{station_id}_test.parquet`
# **Outputs:** separate train-derived and test-derived feature artifacts in `data/processed/`

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# **TODO:** Load each station's train-splits and sealed test Parquets independently. Preserve the physical train/test separation throughout this stage; never concatenate them before feature generation.

# %% [markdown]
# **TODO:** Build lagged/rolling features independently within each physical artifact. Do not use test rows to construct train-derived features.

# %% [markdown]
# **TODO:** Build the multi-step target columns for `FORECAST_HORIZON_HOURS` independently within each physical artifact, retaining `target_valid` and all train-split fold-role columns.

# %% [markdown]
# **TODO:** Write separate train-derived and test-derived feature Parquets to `data/processed/`; do not expose the test-derived artifact to stages 05–07.
