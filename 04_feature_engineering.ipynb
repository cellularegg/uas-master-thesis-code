# %% [markdown]
# # 04 — Feature engineering
#
# Builds the feature matrix used by the training notebooks.
#
# **Inputs:** `data/interim/*.parquet`
# **Outputs:** `data/processed/features.parquet`

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# **TODO:** Load the cleaned series from `data/interim/`.

# %% [markdown]
# **TODO:** Build lagged/rolling features for the univariate series.

# %% [markdown]
# **TODO:** Build the multi-step target columns for `FORECAST_HORIZON_HOURS`.

# %% [markdown]
# **TODO:** Write the feature matrix to `data/processed/` as parquet.
