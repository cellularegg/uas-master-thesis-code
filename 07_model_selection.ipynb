# %% [markdown]
# # 07 — Model selection
#
# Reads logged MLflow metrics across runs and records which model/run wins.
#
# **Inputs:** MLflow runs
# **Outputs:** selected model/run recorded (no `models/` promotion logic yet)

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

import mlflow

# %% [markdown]
# **TODO:** Query MLflow runs across all training notebooks' experiments.

# %% [markdown]
# **TODO:** Rank runs by the chosen evaluation metric.

# %% [markdown]
# **TODO:** Record the winning model/run (no `models/` copy/promotion logic yet).
