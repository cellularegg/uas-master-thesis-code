# %% [markdown]
# # 05 — Train: Ridge regression
#
# Tunes and trains a Ridge regression model on the shared folds.
#
# **Inputs:** `data/processed/features.parquet`, `data/processed/folds.parquet`
# **Outputs:** MLflow run (params/metrics only), `models/ridge.*`

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV, PredefinedSplit

from src.config import FORECAST_HORIZON_HOURS
from src.mlflow_utils import set_experiment, log_run

# %% [markdown]
# **TODO:** Load the feature matrix and the shared fold artifact from `data/processed/`.

# %% [markdown]
# **TODO:** Build a `PredefinedSplit` from the shared fold artifact (not sklearn's default random k-fold, which would leak future data into training).

# %% [markdown]
# **TODO:** Run `GridSearchCV(Ridge(), param_grid, cv=predefined_split)` over the regularization strength.

# %% [markdown]
# **TODO:** Compute evaluation metrics per fold for the best estimator.

# %% [markdown]
# **TODO:** Log params/metrics via `src/mlflow_utils.py` (`set_experiment`, `log_run`).

# %% [markdown]
# **TODO:** Save the trained model to `models/`.
