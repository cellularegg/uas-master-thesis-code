# %% [markdown]
# # 05 — Train: Ridge regression
#
# Tunes and trains a Ridge regression model on the shared folds.
#
# **Inputs:** train-derived feature artifacts only (including shared fold-role columns)
# **Outputs:** MLflow run (params/metrics only), `models/ridge.*`

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# **TODO:** Load only each station's train-derived feature artifact. Do not open the sealed test or test-derived feature artifact during training, tuning, or model selection.

# %% [markdown]
# **TODO:** Build explicit chronological `(train_indices, validation_indices)` pairs from every `fold_XX_role` column, restricting validation to `target_valid`. Do not use a conventional `PredefinedSplit`: one fixed fold assignment cannot represent these overlapping expanding-training roles safely.

# %% [markdown]
# **TODO:** Tune Ridge regularization using only the explicit chronological index pairs from the train-derived artifact.

# %% [markdown]
# **TODO:** Compute evaluation metrics per fold for the best estimator.

# %% [markdown]
# **TODO:** Log params/metrics via `src/mlflow_utils.py` (`set_experiment`, `log_run`).

# %% [markdown]
# **TODO:** Save the trained model to `models/`.
