# %% [markdown]
# # 06 — Evaluate
#
# Compares model performance across the shared folds.
#
# **Inputs:** `data/processed/folds.parquet`, MLflow runs
# **Outputs:** comparison plots/tables (not persisted yet)

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

import pandas as pd
import matplotlib.pyplot as plt
import mlflow

# %% [markdown]
# **TODO:** Query MLflow runs for the persistence and Ridge experiments.

# %% [markdown]
# **TODO:** Aggregate per-fold metrics into a comparison table.

# %% [markdown]
# **TODO:** Plot per-horizon-step error for each model.
