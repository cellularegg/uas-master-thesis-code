# %% [markdown]
# # 06 — Evaluate
#
# Compares model performance across the shared folds.
#
# **Inputs:** train-derived fold metadata/metrics and MLflow runs only
# **Outputs:** comparison plots/tables (not persisted yet)

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# **TODO:** Query cross-validation MLflow runs for the persistence and Ridge experiments. This stage must not open the sealed test or test-derived feature artifact.

# %% [markdown]
# **TODO:** Aggregate development-fold metrics into a comparison table; reserve test metrics for a future post-selection evaluation stage.

# %% [markdown]
# **TODO:** Plot per-horizon-step error for each model.
