# %% [markdown]
# # 06 — Model selection
#
# Reads logged MLflow metrics across runs and records which model/run wins.
#
# **Inputs:** model-reported cross-validation metrics in MLflow runs only
# **Outputs:** selected model/run recorded (no `models/` promotion logic yet)

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# **TODO:** Query model-reported cross-validation metrics across all training notebooks. Do not open the sealed test or test-derived feature artifact during selection.

# %% [markdown]
# **TODO:** Rank runs by the chosen evaluation metric.

# %% [markdown]
# **TODO:** Record the winning model/run (no `models/` copy/promotion logic yet). Opening the test artifact remains a future post-selection final-fit/evaluation step.
