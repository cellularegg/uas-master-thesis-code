# %% [markdown]
# # 06 — Model selection
#
# Reads logged MLflow metrics across runs and records which model/run wins.
#
# **Inputs:** model-reported aggregate cross-validation metrics in MLflow runs only (`cv_mae_mean`, `cv_rmse_mean`, `cv_r2_mean`, and `cv_me_mean`)
#
# **Excluded diagnostics:** every sealed-test metric, including the `sealed_test_quartile` and `sealed_test_alarm` regime phases, is post-hoc evidence and must never influence candidate, hyperparameter, run, or model ranking.
# **Outputs:** selected model/run recorded (no `models/` promotion logic yet)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# **TODO:** Query only model-reported aggregate cross-validation metrics (`cv_mae_mean`, `cv_rmse_mean`, `cv_r2_mean`, and `cv_me_mean`) across all training notebooks. Do not query sealed-test phases or open the sealed test or test-derived feature artifact during selection.

# %% [markdown]
# **TODO:** Rank runs by the chosen aggregate cross-validation metric. Explicitly reject `sealed_test`, `sealed_test_quartile`, and `sealed_test_alarm` rows from any future ranking input.

# %% [markdown]
# **TODO:** Record the winning model/run (no `models/` copy/promotion logic yet). Opening the test artifact remains a future post-selection final-fit/evaluation step.
