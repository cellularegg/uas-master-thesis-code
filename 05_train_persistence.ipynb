# %% [markdown]
# # 05 — Train: persistence baseline
#
# Trains/evaluates the persistence (naive) baseline on the shared folds.
#
# **Inputs:** train-derived feature artifacts only (including shared fold-role columns)
# **Outputs:** MLflow run (params/metrics only), `models/persistence.*`

# %%
## Setup

from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# **TODO:** Load only each station's train-derived feature artifact. Do not open the sealed test or test-derived feature artifact during training, cross-validation, or model selection.

# %% [markdown]
# **TODO:** For each explicit `fold_XX_role` column, use `train` rows to fit/initialize and `validation & target_valid` rows to score; predict the last observed value across `FORECAST_HORIZON_HOURS` steps.

# %% [markdown]
# **TODO:** Compute evaluation metrics per fold.

# %% [markdown]
# **TODO:** Log params/metrics via `src/mlflow_utils.py` (`set_experiment`, `log_run`).

# %% [markdown]
# **TODO:** Save the trained baseline to `models/`.
